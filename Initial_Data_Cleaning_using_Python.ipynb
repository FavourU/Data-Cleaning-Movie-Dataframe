# %% [markdown]
# # **Importing Data Frame**

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bf0b39a0-6743-4a7a-b54b-c84151c7c4f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf0b39a0-6743-4a7a-b54b-c84151c7c4f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['movies.csv']))
# Dataset is now stored in a Pandas Dataframe
df2
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# # **Taking a look at the data**

# %%
df2.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %% [markdown]
# Initial notes:
#
#
#
# *   Year dates aren't in the same format. Some have only one year. Will need to remove the brackets.
# *   Genre and stars have/ start with /n which needs to be removed and there are 3 or more objects in one cell (list) which may need to be seperated for better analysis
#
#
# *   Rating, Votes and Runtime have some NaN's. can check if its necessary to remove these/ fill these
# *   One- line has /n which needs to be removed. need to consider if this column is neccessarry
#
# * Gross seems to have multiple NaN's. Will need to check the percentage to see if this column can be kept

# %%
df2.describe(include = 'object')
# Out:
#                   MOVIES      YEAR                 GENRE        ONE-LINE  \
# count               9999      9355                  9919            9999
# unique              6817       438                   510            8688
# top      Bleach: Burîchi  (2020– )  \nComedy              \nAdd a Plot\n
# freq                  65       892                   852            1265
#
#        STARS VOTES   Gross
# count   9999  8179     460
# unique  7877  4129     332
# top       \n     7  $0.01M
# freq     456    35      22

# %% [markdown]
# Thoughts:
#
#
#
# * Gross has 460 count (out of 9999) which suggests that majority of the data is null. Will need to check for nulls to clarify this.
# *   /n needs to be removed from multiple columns.

# %%
df2.dtypes
# Out:
# MOVIES       object
# YEAR         object
# GENRE        object
# RATING      float64
# ONE-LINE     object
# STARS        object
# VOTES        object
# RunTime     float64
# Gross        object
# dtype: object

# %% [markdown]
# Thoughts:
#
# Year, Votes and Gross are the wrong data types

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
df2.isnull().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %% [markdown]
# Thoughts:
#
#
# *   Gross has too many non- null values and so needs to be removed
#
#
# *   Dont need to remove other columns unless deemed unneccessary to have them as null values not large enough to affect data

# %% [markdown]
# **To do:**
#
#
#
# *   Remove Gross column due to too many null values. will remove one-line as i believe it is unneccessary for analysis
#
# *   Remove brackets from Year column
#
# *   Index year values to keep only first year, Labeled Start Year. The ones that have multiple years are correct - due to being series movies - but can add a column to say series or not. Yes or no. (if neccessary)
#
# *   Remove /n from genre, stars and one-line
#
# *   Split Genre and Stars into multiple more lines/ cells so that it is one word/ genre/ star per cell
# *   Need to decide to backfill or frontfill rating, runtime and votes NaN
#
#
# *   Change data type for year and votes

# %%
df2.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross'],
#       dtype='object')

# %% [markdown]
# # **Cleaning the Data**

# %% [markdown]
# ## Remove Gross and One-line column

# %%
df2.drop(columns = ['Gross', 'ONE-LINE'], axis = 'columns', inplace = True)

# %%
df2
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# ## Remove brackets from Year column

# %%
df2.YEAR
# Out:
# 0            (2021)
# 1          (2021– )
# 2       (2010–2022)
# 3          (2013– )
# 4            (2021)
#            ...
# 9994       (2021– )
# 9995       (2021– )
# 9996       (2022– )
# 9997       (2021– )
# 9998       (2021– )
# Name: YEAR, Length: 9999, dtype: object

# %%
df2['YEAR'] = df2['YEAR'].str.strip('(').str.strip(')')
df2['YEAR']
# Out:
# 0            2021
# 1          2021–
# 2       2010–2022
# 3          2013–
# 4            2021
#           ...
# 9994       2021–
# 9995       2021–
# 9996       2022–
# 9997       2021–
# 9998       2021–
# Name: YEAR, Length: 9999, dtype: object

# %% [markdown]
# ## Index year values to keep only first year, Labeled Start Year.

# %%
df2['Start Year'] = df2['YEAR'].str[:4]
df2['Start Year']
# Out:
# 0       2021
# 1       2021
# 2       2010
# 3       2013
# 4       2021
#         ...
# 9994    2021
# 9995    2021
# 9996    2022
# 9997    2021
# 9998    2021
# Name: Start Year, Length: 9999, dtype: object

# %%
df2
# Out:
#                                    MOVIES       YEAR  \
# 0                           Blood Red Sky       2021
# 1     Masters of the Universe: Revelation     2021–
# 2                        The Walking Dead  2010–2022
# 3                          Rick and Morty     2013–
# 4                         Army of Thieves       2021
# ...                                   ...        ...
# 9994                       The Imperfects     2021–
# 9995                               Arcane     2021–
# 9996                    Heart of Invictus     2022–
# 9997                       The Imperfects     2021–
# 9998                       The Imperfects     2021–
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# ## Create a 'series' column based on Year column

# %%
df2['char_length'] = df2['YEAR'].str.len()
df2
# Out:
#                                    MOVIES       YEAR  \
# 0                           Blood Red Sky       2021
# 1     Masters of the Universe: Revelation     2021–
# 2                        The Walking Dead  2010–2022
# 3                          Rick and Morty     2013–
# 4                         Army of Thieves       2021
# ...                                   ...        ...
# 9994                       The Imperfects     2021–
# 9995                               Arcane     2021–
# 9996                    Heart of Invictus     2022–
# 9997                       The Imperfects     2021–
# 9998                       The Imperfects     2021–
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df2['Series'] = np.where(df2['char_length'] > 4, True, False)
df2.head()
# Out:
#                                 MOVIES       YEAR  \
# 0                        Blood Red Sky       2021
# 1  Masters of the Universe: Revelation     2021–
# 2                     The Walking Dead  2010–2022
# 3                       Rick and Morty     2013–
# 4                      Army of Thieves       2021
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                                STARS    VOTES  RunTime  \
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0
# 1  \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0
# 2  \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0
# ...

# %%
#Will remove 'year' and 'char_length' columns as they are unneeded but will create a new data frame to continue with this
df3 = df2.drop(columns = ['YEAR','char_length'], axis = 'columns',)
df3
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# ...

# %%
#Will change True/ false to yes/no
df3 =df3.replace({'Series': {True : 'yes', False: 'no'}})
df3
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# ...

# %% [markdown]
# ## Remove /n from Genre

# %%
df3.columns
# Out:
# Index(['MOVIES', 'GENRE', 'RATING', 'STARS', 'VOTES', 'RunTime', 'Start Year',
#        'Series'],
#       dtype='object')

# %%
df3.GENRE
# Out:
# 0           \nAction, Horror, Thriller
# 1       \nAnimation, Action, Adventure
# 2            \nDrama, Horror, Thriller
# 3       \nAnimation, Adventure, Comedy
# 4              \nAction, Crime, Horror
#                            ...
# 9994       \nAdventure, Drama, Fantasy
# 9995    \nAnimation, Action, Adventure
# 9996              \nDocumentary, Sport
# 9997       \nAdventure, Drama, Fantasy
# 9998       \nAdventure, Drama, Fantasy
# Name: GENRE, Length: 9999, dtype: object

# %%
df3['GENRE'] = df3['GENRE'].str.strip('\n')
df3
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 NaN
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 NaN
# ...

# %% [markdown]
# ## Adding delimeters so that Stars can be split into into Director and Actors

# %%
df3
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 NaN
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 NaN
# ...

# %%
df3['STARS'] = df3['STARS'].str.replace('Director:\n','0 ', regex=False).str.replace('Stars:\n','1 ', regex=False)
df3
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 NaN
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 NaN
# ...

# %%
df3['STARS'] = df3['STARS'].str.replace('\n','N/A', regex=False)
df3
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 NaN
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 NaN
# ...

# %%
df3['STARS'] = df3['STARS'].str.replace('N/A|',' ', regex=False)
df3.head(2)
# Out:
#                                 MOVIES  \
# 0                        Blood Red Sky
# 1  Masters of the Universe: Revelation
#
#                                       GENRE  RATING  \
# 0      Action, Horror, Thriller                 6.1
# 1  Animation, Action, Adventure                 5.0
#
#                                                STARS   VOTES  RunTime  \
# 0  N/A    0 Peter Thorwarth  N/A    1 Peri Baumei...  21,062    121.0
# 1  N/A            N/A    1 Chris Wood, N/ASarah M...  17,870     25.0
#
#   Start Year Series
# 0       2021     no
# 1       2021    yes

# %%
df3.STARS[9996]
# Out:
# 'N/A    0 Orlando von Einsiedel  N/A    Star:N/APrince HarryN/A'

# %%
df3['STARS'] = df3['STARS'].str.replace('Star:N/A','1 ', regex=False)

# %%
df3.STARS[9996]
# Out:
# 'N/A    0 Orlando von Einsiedel  N/A    1 Prince HarryN/A'

# %%
df3.loc[df3['STARS'] == 'N/A']
# Out:
#                                       MOVIES  \
# 24    He-Man and the Masters of the Universe
# 1027             Myth & Mogul: John DeLorean
# 1380          Love is Blind: After the Altar
# 1419              Avatar: The Last Airbender
# 1454     Cocaine Cowboys: The Kings of Miami
# ...                                      ...
# 9972                             Sonic Prime
# 9973                             Sonic Prime
# 9974                             Sonic Prime
# 9986                        The Last Kingdom
# 9995                                  Arcane
#
#                                           GENRE  RATING STARS VOTES  RunTime  \
# 24     Animation, Action, Adventure                 NaN   N/A   NaN      NaN
# 1027  Documentary, Biography, Crime                 7.0   N/A   213      NaN
# 1380                     Reality-TV                 5.4   N/A    39     45.0
# 1419     Action, Adventure, Fantasy                 NaN   N/A   NaN      NaN
# ...

# %%
df3.loc[df3['STARS'] == 'N/A', 'STARS'] = 'N/A 1 N/A'

# %%
df3
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 NaN
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 NaN
# ...

# %%
df3['STARS'].str.contains('1').sum()
# Out:
# 9662

# %%
#Current dilemma is that around 337 rows do not have '1' in them (as found from above)
#Need to figure out how to identify the index of those rows
#Then i want to check what i need to edit to change them to have ones
#This should allow me to then seperate the columns due to the '1'

# %%
df3[~df3["STARS"].str.contains("1")]
# Out:
#                                           MOVIES  \
# 1367               El caso Wanninkhof-Carabantes
# 1469                                   Pray Away
# 1658  The Chronicles of Narnia: The Silver Chair
# 2052              If Anything Happens I Love You
# 2178                Untold: Malice at the Palace
# ...                                          ...
# 9988                            The Last Kingdom
# 9989                                        1899
# 9990                                        1899
# 9991                                        1899
# 9992                                        1899
#
#                                         GENRE  RATING  \
# 1367  Documentary, Crime, History                 6.5
# 1469                  Documentary                 6.2
# 1658           Adventure, Fantasy                 NaN
# 2052      Animation, Short, Drama                 7.8
# 2178           Documentary, Sport                 NaN
# ...

# %% [markdown]
# Noticed that RunTime, Votes and Rating are NaN for some of these rows, Would it be better to remove the rows?
# df4 = df3.dropna(subset=['RATING', 'VOTES', 'RunTime'])

# %%
#df4 = df3.dropna(subset=['RATING', 'VOTES', 'RunTime'], thresh=len(['RATING', 'VOTES', 'RunTime']))
df4 = df3.dropna(subset=['RATING', 'VOTES', 'RunTime'])
df4
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 5                             Outer Banks
# ...                                   ...
# 9959                               Sexify
# 9960                               Sexify
# 9961                               Sexify
# 9962                               Sexify
# 9963                          Castlevania
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 5             Action, Crime, Drama                 7.6
# ...                                        ...     ...
# 9959                 Comedy, Drama                 6.8
# ...

# %%
#This would remove 1/3 of the data, so should probably not drop it
